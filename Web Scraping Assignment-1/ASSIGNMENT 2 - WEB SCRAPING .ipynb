# %% [markdown]
# # Q 1

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title), len(job_location), len(company_name), len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                               Title  \
# 0                                      Data Analyst
# 1                                      Data Analyst
# 2                           Hiring For Data Analyst
# 3                         Data Analyst- Yulu Energy
# 4                                      Data Analyst
# 5  Urgently required Data analyst - Microsoft Azure
# 6                                      Data Analyst
# 7                                      Data Analyst
# 8                                      Data Analyst
# 9                           Data Analyst Databricks
#
#                                             Location  \
# 0                       Hybrid - Bangalore/Bengaluru
# 1                                   Permanent Remote
# 2                       Hybrid - Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5  Hybrid - Bangalore/Bengaluru, Hyderabad/Secund...
# ...

# %% [markdown]
# # Q 2

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title), len(job_location), len(company_name))
# Out:
# 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name})
df
# Out:
#                               Title  \
# 0           Data Science Specialist
# 1  Analystics & Modeling Specialist
# 2                    Data Scientist
# 3                Sr. Data scientist
# 4                    Data Scientist
# 5              Staff Data Scientist
# 6             Expert Data Scientist
# 7    SR. SPECIALIST, DATA ANALYTICS
# 8             Senior Data Scientist
# 9                    Data Scientist
#
#                                             Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 3  Bangalore/Bengaluru, Hyderabad/Secunderabad, M...
# 4  Bangalore/Bengaluru, Noida, Kolkata, Mumbai, H...
# 5                        Bangalore/Bengaluru, Mumbai
# 6                        Bangalore/Bengaluru, Mumbai
# 7                                Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Q 3

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
check_box_element = driver.find_element(By.XPATH, '//input[@id="chk-Delhi / NCR-cityTypeGid-"]')
driver.execute_script("arguments[0].click();", check_box_element)

# %%
check_box_element = driver.find_element(By.XPATH, '//input[@id="chk-3-6 Lakhs-ctcFilter-"]')
driver.execute_script("arguments[0].click();", check_box_element)

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title), len(job_location), len(company_name), len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title  \
# 0                        Data Scientist data Analyst
# 1                  Data Scientist - Engine Algorithm
# 2                               Analyst-Data Science
# 3                               Analyst-Data Science
# 4                 Senior Data Scientist - Statistics
# 5                                     Data Scientist
# 6  SQL Server Developer :: MNC :: Health Care :: ...
# 7                                     Data Scientist
# 8                Associate Data Scientist - ML & NLP
# 9   Data Scientist-Work from Office-Contractual Role
#
#                                             Location  \
# 0  Delhi / NCR, Kolkata, Hyderabad/Secunderabad, ...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2                                   Gurgaon/Gurugram
# 3                                   Gurgaon/Gurugram
# 4                                   Gurgaon/Gurugram
# 5  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# ...

# %% [markdown]
# # Q 4

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
close = driver.find_element(By.CLASS_NAME, "_2KpZ6l._2doB4z")
close.click()

# %%
designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
page_num=input("Enter number of pages")
for i in range(1,int(page_num)+1):
    driver.get("https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i))
# Out:
# Enter number of pages2

# %%
title_Brand=[]
Product_Description=[]
title_Price=[]

# %%
Brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand_tags[0:40]:
    Brand=i.text
    title_Brand.append(Brand)

Description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Description_tags[0:40]:
    Description=i.text
    Product_Description.append(Description)

Price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in Price_tags[0:40]:
    Price=i.text
    title_Price.append(Price)

# %%
print(len(title_Brand), len(Product_Description), len(title_Price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Brand':title_Brand,'Description':Product_Description,'Price':title_Price})
df
# Out:
#              Brand                                        Description   Price
# 0           GANSTA    Gradient, UV Protection Aviator Sunglasses (57)    ₹299
# 1        Elligator                UV Protection Round Sunglasses (53)    ₹149
# 2   kingsunglasses  UV Protection, Night Vision Wayfarer Sunglasse...    ₹281
# 3        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹129
# 4    VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...    ₹690
# 5           PIRASO              Polarized Wrap-around Sunglasses (45)    ₹397
# 6           PIRASO             UV Protection Wayfarer Sunglasses (32)    ₹251
# 7            NuVew   UV Protection, Mirrored Wayfarer Sunglasses (57)     ₹99
# 8           PIRASO           UV Protection Over-sized Sunglasses (65)    ₹342
# 9           GANSTA  UV Protection, Gradient Wayfarer, Round Sungla...    ₹299
# 10       Rich Club         UV Protection Retro Square Sunglasses (54)    ₹274
# ...

# %% [markdown]
# # Q 5

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
page_num=input("Enter number of pages")
for i in range(1,int(page_num)+1):
    driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market=&page="+str(i))

# %%
iphone_Rating=[]
Review_Summary=[]
Full_Review=[]

# %%
Rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in Rating_tags[0:100]:
    Rating=i.text
    iphone_Rating.append(Rating)

Summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in Summary_tags[0:100]:
    Summary=i.text
    Review_Summary.append(Summary)

Review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in Review_tags[0:100]:
    Review=i.text
    Full_Review.append(Review)

# %%
print(len(iphone_Rating), len(Review_Summary), len(Full_Review))
# Out:
# 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Rating':iphone_Rating,'Summary':Review_Summary,'Review':Full_Review})
df
# Out:
#   Rating              Summary  \
# 0      5       Simply awesome
# 1      5     Perfect product!
# 2      5  Best in the market!
# 3      4      Value-for-money
# 4      5   Highly recommended
# 5      5    Worth every penny
# 6      5     Perfect product!
# 7      4          Pretty good
# 8      5   Highly recommended
# 9      5        Great product
#
#                                               Review
# 0  Really satisfied with the Product I received.....
# 1  Amazing phone with great cameras and better ba...
# 2  Great iPhone very snappy experience as apple k...
# 3  I'm Really happy with the product\nDelivery wa...
# 4  It's my first time to use iOS phone and I am l...
# 5  Previously I was using one plus 3t it was a gr...
# 6  Value for money\n5 star rating\nExcellent came...
# 7  I was using Iphone 6s and also Oneplus 6t. Bot...
# 8  What a camera .....just awesome ..you can feel...
# 9  Amazing Powerful and Durable Gadget.\n\nI’m am...

# %% [markdown]
# # Q 6

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
close = driver.find_element(By.CLASS_NAME, "_2KpZ6l._2doB4z")
close.click()

# %%
designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
page_num=input("Enter number of pages")
for i in range(1,int(page_num)+1):
    driver.get("https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i))
# Out:
# Enter number of pages3

# %%
title_Brand=[]
Product_Description=[]
title_Price=[]

# %%
Brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand_tags[0:40]:
    Brand=i.text
    title_Brand.append(Brand)

Description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Description_tags[0:40]:
    Description=i.text
    Product_Description.append(Description)

Price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in Price_tags[0:40]:
    Price=i.text
    title_Price.append(Price)

# %%
print(len(title_Brand), len(Product_Description), len(title_Price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Brand':title_Brand,'Description':Product_Description,'Price':title_Price})
df
# Out:
#                     Brand                                        Description  \
# 0                    PUMA                          Brisk FR Sneakers For Men
# 1                  Kraasa                                 Sneakers For Women
# 2                    PUMA                             Throb Sneakers For Men
# 3                      TR  Casual Shoes| Caual Sneakers| White Sneakers F...
# 4   HRX by Hrithik Roshan                                   Sneakers For Men
# 5                   BIRDE  Combo Pack of 2 Premium Sports Shoes Sneakers ...
# 6             Asian Shoes  Future-04 casual shoes for men | Latest Stylis...
# 7                RapidBox                                   Sneakers For Men
# 8                    PUMA                 Entrant Slipon MU Sneakers For Men
# 9             bacca bucci                                   Sneakers For Men
# 10                   PUMA                RBR Electron E Pro Sneakers For Men
# ...

# %% [markdown]
# # Q 7

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
search_field = driver.find_element(By.ID, 'twotabsearchtextbox')
search_field.send_keys('Laptop')

# %%
search_button = driver.find_element(By.ID, 'nav-search-submit-button')
search_button.click()

# %%
check_box_element = driver.find_element(By.XPATH, '//*[@id="filters"]/ul[7]')
driver.execute_script("arguments[0].click();", check_box_element)

# %%
check_box_element = driver.find_element(By.XPATH, '//*[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
driver.execute_script("arguments[0].click();", check_box_element)

# %%
laptop_title=[]
laptop_rating=[]
laptop_Price=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]')
for i in title_tags[0:10]:
    title = i.text
    laptop_title.append(title)
    
rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in rating_tags[0:10]:
    rating=i.text
    laptop_rating.append(rating)

Price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in Price_tags[0:10]:
    Price=i.text
    laptop_Price.append(Price)

# %%
print(len(laptop_title), len(laptop_rating), len(laptop_Price))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'title':laptop_title,'rating':laptop_rating,'Price':laptop_Price})
df
# Out:
#                                                title rating     Price
# 0  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...    3.4    24,889
# 1  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...    4.1    56,990
# 2  Lenovo ThinkPad P14s Mobile Workstation 11th G...    5.0    45,592
# 3  (Renewed) Dell Latitude E7470 Intel Core i7 6t...    4.0  1,03,990
# 4  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...    4.0    30,000
# 5  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...    4.3    95,990
# 6  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...    3.1    89,990
# 7  HP Envy x360 2-in-1 Laptop 12th Gen Intel core...    4.0  1,14,990
# 8  Lenovo IdeaPad Flex 5 Intel Core i7 11th Gen 1...    3.4  1,16,505
# 9  HP Victus 12th Gen Intel Core i7 15.6 inch(39....    3.3    95,490

# %% [markdown]
# # Q 8

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.azquotes.com/")

# %%
top_quotes=driver.find_element(By.XPATH,'//*[@id="menu"]/div/div[3]/ul/li[5]/a')
top_quotes.click()

# %%
page_num=input("Enter number of pages")
for i in range(1,int(page_num)+1):
    driver.get("https://www.azquotes.com/top_quotes.html?p="+str(i))
# Out:
# Enter number of pages2

# %%
list_Quote=[]
list_Author=[]
quote_Type=[]

# %%
Quote_tags = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in Quote_tags[0:1000]:
    Quote = i.text
    list_Quote.append(Quote)

Author_tags = driver.find_elements(By.XPATH, '//div[@class="author"]')
for i in Author_tags[0:1000]:
    Author = i.text
    list_Author.append(Author)
    
Type_tags = driver.find_elements(By.XPATH, '//div[@class="tags"]')
for i in Type_tags[0:1000]:
    Type = i.text
    quote_Type.append(Type)

# %%
print(len(list_Quote), len(list_Author), len(quote_Type))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Quote':list_Quote,'Author':list_Author,'Type of Quote':quote_Type})
df
# Out:
#                                                 Quote                 Author  \
# 0   Can words describe the fragrance of the very b...        Neltje Blanchan
# 1   When everything seems to be going against you,...             Henry Ford
# 2   Faith is to believe what you do not see; the r...        Saint Augustine
# 3   I have found that if you love life, life will ...      Arthur Rubinstein
# 4   To disarm the people... was the best and most ...           George Mason
# ..                                                ...                    ...
# 95  When one door closes, another opens; but we of...  Alexander Graham Bell
# 96                   Don't find fault, find a remedy.             Henry Ford
# 97  I used to think the worst thing in life was to...         Robin Williams
# 98  Friends and good manners will carry you where ...        Margaret Walker
# 99  If you want to make a permanent change, stop f...           T. Harv Eker
#
#                             Type of Quote
# ...

# %% [markdown]
# # Q 9

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.jagranjosh.com/")

# %%
gk_option=driver.find_element(By.LINK_TEXT,"GK")
gk_option.click()

# %%
pm_option=driver.find_element(By.LINK_TEXT,"List of all Prime Ministers of India")
pm_option.click()

# %%
pm_name=driver.find_elements(By.XPATH,'//div[@class="table-box"]//tbody//tr//td[2]//p')

born_dead=driver.find_elements(By.XPATH,'//div[@class="table-box"]//tbody//tr//td[3]//p')

office_term=driver.find_elements(By.XPATH,'//div[@class="table-box"]//tbody//tr//td[4]//p')

remarks_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"]//tbody//tr//td[5]//p')

# %%
pm_data=[]

# %%
for i in range(len(pm_name)):
    temporary_data={'Name': pm_name[i].text, 
                    'Born-Dead': born_dead[i].text,
                     'Term of office': office_term[i].text,
                     'Remarks': remarks_tags[i].text}
    pm_data.append(temporary_data)

# %%
df_data=pd.DataFrame(pm_data)
df_data
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                         Term of office  \
# ...

# %% [markdown]
# # Q 10

# %%
import selenium
import pandas as pd 
from selenium import webdriver 
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By 
import time
from selenium.webdriver.support.ui import Select

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.motor1.com/")

# %%
menu=driver.find_element(By.CLASS_NAME, "m1-hamburger-button")
menu.click()

# %%
dropdown=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[5]/button")
dropdown.click()

# %%
LISTS=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a")
LISTS.click()

# %%
expensive_car=driver.find_element(By.XPATH, "/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[4]/div/div[1]/h3/a")
expensive_car.click()

# %%
car_name=[]
car_price=[]

# %%
name_tags = driver.find_elements(By.XPATH, '//h3[@class="subheader"]')
for i in name_tags[0:50]:
    name = i.text
    car_name.append(name)

price_tags = driver.find_elements(By.XPATH, '//*[@id="article_box"]/div[1]/div[2]/div[1]/p/strong')
for i in price_tags[0:50]:
    price = i.text
    car_price.append(price)

# %%
print(len(car_name), len(car_price))
# Out:
# 50 50

# %%
import pandas as pd
df=pd.DataFrame({'Name':car_name,'Price':car_price})
df
# Out:
#                                Name                 Price
# 0                     De Tomaso P72   Price: $1.3 Million
# 1                 Ferrari LaFerrari   Price: $1.4 Million
# 2                     Pagani Huayra   Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C   Price: $1.7 Million
# 5                     Ferrari Monza   Price: $1.7 Million
# 6                Gordon Murray T.33   Price: $1.7 Million
# 7                 Koenigsegg Gemera   Price: $1.7 Million
# 8                       Zenvo TSR-S   Price: $1.7 Million
# 9                Hennessey Venom F5   Price: $1.7 Million
# 10                  Bentley Bacalar   Price: $1.8 Million
# 11    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 12           Bentley Mulliner Batur   Price: $1.9 Million
# 13                     Deus Vayanne   Price: $2.0 Million
# 14                      SSC Tuatara   Price: $2.0 Million
# 15                      Lotus Evija  Price: $2.0 Million*
# ...
